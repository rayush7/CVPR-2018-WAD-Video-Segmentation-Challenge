# %%
import numpy as np
import pandas as pd
import numpy as np                                
from skimage import measure                       
import create_dataset
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sample_train_color = '/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_train_color'
sample_train_label = '/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_train_label'

sample_val_color = '/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_val_color'
sample_val_label = '/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_val_label'

sample_test_color = '/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_test'

# %%
train_img_path_list = os.listdir(sample_train_color)
train_img_path_list = [os.path.join(sample_train_color,x) for x in train_img_path_list]

train_label_path_list = os.listdir(sample_train_label)
train_label_path_list = [os.path.join(sample_train_label,x) for x in train_label_path_list]

val_img_path_list = os.listdir(sample_val_color)
val_img_path_list = [os.path.join(sample_val_color,x) for x in val_img_path_list]

val_label_path_list = os.listdir(sample_val_label)
val_label_path_list = [os.path.join(sample_val_label,x) for x in val_label_path_list]

test_img_path_list = os.listdir(sample_test_color)
test_img_path_list = [os.path.join(sample_test_color,x) for x in test_img_path_list]

train_img_path_list.sort()
train_label_path_list.sort()
val_img_path_list.sort()
val_label_path_list.sort()

#train_img_path_list = train_img_path_list[0:5]
#train_label_path_list = train_label_path_list[0:5]

#val_img_path_list = val_img_path_list[0:5]
#val_label_path_list = val_label_path_list[0:5]

#print(train_img_path_list[0:5])
#print('--------------')
#print(val_img_path_list[0:5])

# %%
from skimage.io import imread

img = imread('/home/ayush/Instance_Segmentation/all/Sample_Dataset/sample_train_color/171206_025742296_Camera_6.jpg')
plt.imshow(img)
plt.show()

# %%
create_dataset.create_coco(train_img_path_list,train_label_path_list,'/home/ayush/Instance_Segmentation/all/Sample_Dataset/wad_sample_train.json')
# Out:
# 6it [00:00, 51.05it/s]
# Creating image list...
# Creating object2color dictionary...
# 5804it [01:31, 63.10it/s]
# 0it [00:00, ?it/s]
# Creating annotation list...
# 2it [00:00,  2.28it/s]
# Image ID  1 could not find the bounding boxs
# 3it [00:01,  2.34it/s]
# Image ID  2 could not find the bounding boxs
# 5it [00:02,  2.46it/s]
# Image ID  4 could not find the bounding boxs
# 11it [00:04,  2.56it/s]
# Image ID  10 could not find the bounding boxs
# 12it [00:04,  2.54it/s]
# Image ID  11 could not find the bounding boxs
# Image ID  11 could not find the bounding boxs
# Image ID  11 could not find the bounding boxs
# 13it [00:05,  2.54it/s]
# Image ID  12 could not find the bounding boxs
# 14it [00:05,  2.47it/s]
# Image ID  13 could not find the bounding boxs
# Image ID  13 could not find the bounding boxs
# 16it [00:06,  2.43it/s]
# Image ID  15 could not find the bounding boxs
# 18it [00:07,  2.36it/s]
# Image ID  17 could not find the bounding boxs
# ...

# %%
create_dataset.create_coco(val_img_path_list,val_label_path_list,'/home/ayush/Instance_Segmentation/all/Sample_Dataset/wad_sample_val.json')
# Out:
# 7it [00:00, 66.06it/s]
# Creating image list...
# Creating object2color dictionary...
# 2496it [00:39, 62.71it/s]
# 0it [00:00, ?it/s]
# Creating annotation list...
# 82it [00:30,  2.83it/s]
# Image ID  81 could not find the bounding boxs
# 84it [00:31,  2.80it/s]
# Image ID  83 could not find the bounding boxs
# 155it [00:56,  2.83it/s]
# Image ID  154 could not find the bounding boxs
# 164it [00:59,  2.75it/s]
# Image ID  163 could not find the bounding boxs
# 167it [01:00,  2.63it/s]
# Image ID  166 could not find the bounding boxs
# 170it [01:01,  2.59it/s]
# Image ID  169 could not find the bounding boxs
# 171it [01:02,  2.63it/s]
# Image ID  170 could not find the bounding boxs
# 174it [01:03,  2.69it/s]
# Image ID  173 could not find the bounding boxs
# 185it [01:07,  2.78it/s]
# Image ID  184 could not find the bounding boxs
# 186it [01:07,  2.78it/s]
# Image ID  185 could not find the bounding boxs
# 188it [01:08,  2.78it/s]
# Image ID  187 could not find the bounding boxs
# ...
